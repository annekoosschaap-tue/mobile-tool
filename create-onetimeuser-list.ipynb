# %%
import requests

def create_onetimeuser(token):
    response = requests.get(
        "https://gateway.cfilab.philips.com/iam/onetimeuser",
        headers = {
            "Accept": "text/plain"
        },
        cookies={"Philips.CFI.AccessToken": token}
    )
    if response.ok:
        try:
            onetimeuser_token = response.text
            return onetimeuser_token
        except Exception as e:
            print(f"Could not create onetimeuser: {e}")

token = 'eyJ0eXAiOiJKV1QiLCJhbGciOiJSUzI1NiIsImtpZCI6IjBmNzcwYjQ2YmFhNGRiMjEzM2EyMjcyNGVhMDcwODgzZjk2MWEwODcifQ.eyJpc3MiOiJodHRwczovL2dhdGV3YXkuY2ZpbGFiLnBoaWxpcHMuY29tIiwic3ViIjoiYS5zY2hhYXBAdHVlLm5sIiwiZXhwIjoxNzcxMjcwMjAwLCJpYXQiOjE3NzEyNDIyNDh9.xBANDPCcwt-qcw1i6qzqbDkiXWoeo_A86jCmb1KEq1hwt8roTl0oKbQ-tdjWoPkH-FuDnxc8q44JY-WHgp8xIu_ZE0tvPeUbf2FnOWYxwCuDacc2DsfhmrUyuag7OJ7MuBSfTvHkHaWppytBiQfMWKIbnxyQLUU3vI6Xiv7qzrZe8PJgsRWjJkyaINpg3VgweOz9m5Wx4qvo08F0j0jJpNAP7Y7qamIURqnDLZU48JLWjqeDP0y7wPpBRxh8Ulztwx7nRZb8PP7wHvbAZKb71VGX3Q2qDrmRnZAfOlZRO19i5xYQIWD-9ZMfoM_iGYWkztjk4jPdRKiqOqPDbesppeIw9x0QekYIA7SqPhsJX4aOkIY5mgQ_CR83W7Ac6sAHPi7W-Yy-moozHr3BpbHTAcLYDdSPjNJ4tmcvCRocrsWOXVfNYvwILSOO0hN5FlB-FH70sArDiYLi7A2VpDt9C3RCXXiTwqcczDb523LPpLac_RwIZVZl-NPiWRxVKScfkN5hAhURTrL-pZvYHfnniBjc_iIUJuO8Io-7aLCPitGoNVI66-WynKTYK9nJ0BrinD7IlC6E52Zm9S9vIw2nLa9__r-Zbk8f5esKt1vysDtZ6bT6OPahtIGeUh2W69ZlJMC7gaBvoxfNSYXCb_hbFXD_9bBRzqTnC-bsH06sFi4'
onetimeuser_token = create_onetimeuser(token)

# %%
nr_of_users = 5
user_list = []
for i in range(nr_of_users):
    user = create_onetimeuser(token)
    user_list.append(user)

# %%
for i in range(len(user_list)):
    print(user_list[i])
# Out:
# eyJ0eXAiOiJKV1QiLCJhbGciOiJSUzI1NiIsImtpZCI6IjBmNzcwYjQ2YmFhNGRiMjEzM2EyMjcyNGVhMDcwODgzZjk2MWEwODcifQ.eyJpc3MiOiJodHRwczovL2dhdGV3YXkuY2ZpbGFiLnBoaWxpcHMuY29tIiwic3ViIjoiZGI3ZTdlYTYtMjA2Mi00ZGJjLWFkYWMtZjlkYmJiNzQ5NGFjIiwiZXhwIjoxNzcxMjc1NjAwLCJpYXQiOjE3NzEyNDY4OTl9.mMKdyHEf4G7on_GJjWC80KxfVgwDHEmi7t6p_mxD4W0Mkcr8eo7Lehtj3dE20L2VP4d_ZkF6wwzZp96tEOMea7IAVfb